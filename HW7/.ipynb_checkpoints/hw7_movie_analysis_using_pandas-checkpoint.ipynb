# %% [markdown]
# # HW7 (total points 6)
#
# # Use pandas API to finish problem in this notebook.
#
# https://pandas.pydata.org/pandas-docs/stable/reference/index.html
#
# Total points 6

# %%
#you may want to import some other modules here such as seaborn or matplotlib
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
from collections import defaultdict

# %%
from io import BytesIO
from zipfile import ZipFile
import requests

# %% [markdown]
# **Let download movie lense dataset [MovieLens](https://grouplens.org/datasets/movielens/) and extract zip file using various python packages**
#
# http://files.grouplens.org/datasets/movielens/ml-latest-small.zip

# %%
r = requests.get("http://files.grouplens.org/datasets/movielens/ml-latest-small.zip")
print(r.status_code)
zipfile = ZipFile(BytesIO(r.content))
# Out:
# 200

# %%
zipfile.extractall()

# %%
! ls ml-latest-small/
# Out:
# README.txt  links.csv   movies.csv  ratings.csv tags.csv

# %%
! head  ./ml-latest-small/movies.csv
# Out:
# movieId,title,genres
# 1,Toy Story (1995),Adventure|Animation|Children|Comedy|Fantasy
# 2,Jumanji (1995),Adventure|Children|Fantasy
# 3,Grumpier Old Men (1995),Comedy|Romance
# 4,Waiting to Exhale (1995),Comedy|Drama|Romance
# 5,Father of the Bride Part II (1995),Comedy
# 6,Heat (1995),Action|Crime|Thriller
# 7,Sabrina (1995),Comedy|Romance
# 8,Tom and Huck (1995),Adventure|Children
# 9,Sudden Death (1995),Action

# %% [markdown]
# **It is a csv file.** We can use pandas read_csv to read this file into pandas DataFrame

# %%
# lets read movies.csv file
movie = pd.read_csv('./ml-latest-small/movies.csv')

movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# # Q1 (.25 point) Check if any of the columns are null

# %%
# write pandas code here
movie.isnull().values.any()
# Out:
# False

# %% [markdown]
# # Q 2 (.25 point) Check datatype of each of the columns

# %%
# write pandas code here
movie.dtypes
# Out:
# movieId     int64
# title      object
# genres     object
# dtype: object

# %% [markdown]
# # Q3 (.5 point) Using *str* on series genres, build following  unique_genre set. It should contain all the unique genres from genres column. Print unique genres too.

# %%
# write pandas code here
unique_genre = movie.genres.str.split("|").sum()
unique_genre = set(unique_genre)
unique_genre
# Out:
# {'(no genres listed)',
#  'Action',
#  'Adventure',
#  'Animation',
#  'Children',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Fantasy',
#  'Film-Noir',
#  'Horror',
#  'IMAX',
#  'Musical',
#  'Mystery',
#  'Romance',
#  'Sci-Fi',
#  'Thriller',
#  'War',
#  'Western'}

# %% [markdown]
# # Q 4 (1 point) Build columns for different genres with value True or False based on whether a genre is present or not in an observation?

# %%
# write pandas code here
for g in unique_genre:
    movie[g] = movie.genres.map(lambda x: g in x.split('|'))
movie
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  Animation  Fantasy   IMAX  \
# 0     Adventure|Animation|Children|Comedy|Fantasy       True     True  False
# 1                      Adventure|Children|Fantasy      False     True  False
# 2                                  Comedy|Romance      False    False  False
# 3                            Comedy|Drama|Romance      False    False  False
# 4                                          Comedy      False    False  False
# ...                                           ...        ...      ...    ...
# 9737              Action|Animation|Comedy|Fantasy       True     True  False
# 9738                     Animation|Comedy|Fantasy       True     True  False
# 9739                                        Drama      False    False  False
# 9740                             Action|Animation       True    False  False
# 9741                                       Comedy      False    False  False
#
#       (no genres listed)  Crime  Film-Noir  Action  ...  Mystery  Comedy  \
# 0                  False  False      False   False  ...    False    True
# 1                  False  False      False   False  ...    False   False
# 2                  False  False      False   False  ...    False    True
# 3                  False  False      False   False  ...    False    True
# 4                  False  False      False   False  ...    False    True
# ...                  ...    ...        ...     ...  ...      ...     ...
# 9737               False  False      False    True  ...    False    True
# 9738               False  False      False   False  ...    False    True
# 9739               False  False      False   False  ...    False   False
# 9740               False  False      False    True  ...    False   False
# 9741               False  False      False   False  ...    False    True
#
#         War  Documentary  Musical  Thriller  Drama  Romance  Horror  Adventure
# 0     False        False    False     False  False    False   False       True
# 1     False        False    False     False  False    False   False       True
# 2     False        False    False     False  False     True   False      False
# 3     False        False    False     False   True     True   False      False
# 4     False        False    False     False  False    False   False      False
# ...     ...          ...      ...       ...    ...      ...     ...        ...
# 9737  False        False    False     False  False    False   False      False
# 9738  False        False    False     False  False    False   False      False
# 9739  False        False    False     False   True    False   False      False
# 9740  False        False    False     False  False    False   False      False
# 9741  False        False    False     False  False    False   False      False
#
# [9742 rows x 23 columns]

# %% [markdown]
# # Q5(1 point) Build a "year" column in movie data frame. The title "year" should be embedded in title columns.

# %% [markdown]
# Python regular expression  package **re** is very useful tool for text data handling.  This excercise is a very primitive use of it.
#
#
# note
# - . mean any character
# - *. means "0 or more instances of the preceding regex token
# - \[ matches a literal [ character
# - [A-Za-z0-9] digits and lower, upper case, I think same as \w+
# - '+' matches one more more times
# - \d Matches any decimal digit

# %%
# write pandas code here
import re 
years = re.compile(r'\([0-9]{4}\)')
yearsLists = [years.findall(movie.title[i]) for i in range(len(movie))]
yearsLists
yearList = []
for years in yearsLists:
    try:
        yearList.append(years[0].replace("(","").replace(")",""))
    except: 
        yearList.append('NA')
movie['Year'] = yearList
movie
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres  Animation  Fantasy   IMAX  \
# 0     Adventure|Animation|Children|Comedy|Fantasy       True     True  False
# 1                      Adventure|Children|Fantasy      False     True  False
# 2                                  Comedy|Romance      False    False  False
# 3                            Comedy|Drama|Romance      False    False  False
# 4                                          Comedy      False    False  False
# ...                                           ...        ...      ...    ...
# 9737              Action|Animation|Comedy|Fantasy       True     True  False
# 9738                     Animation|Comedy|Fantasy       True     True  False
# 9739                                        Drama      False    False  False
# 9740                             Action|Animation       True    False  False
# 9741                                       Comedy      False    False  False
#
#       (no genres listed)  Crime  Film-Noir  Action  ...  Comedy    War  \
# 0                  False  False      False   False  ...    True  False
# 1                  False  False      False   False  ...   False  False
# 2                  False  False      False   False  ...    True  False
# 3                  False  False      False   False  ...    True  False
# 4                  False  False      False   False  ...    True  False
# ...                  ...    ...        ...     ...  ...     ...    ...
# 9737               False  False      False    True  ...    True  False
# 9738               False  False      False   False  ...    True  False
# 9739               False  False      False   False  ...   False  False
# 9740               False  False      False    True  ...   False  False
# 9741               False  False      False   False  ...    True  False
#
#       Documentary  Musical  Thriller  Drama  Romance  Horror  Adventure  Year
# 0           False    False     False  False    False   False       True  1995
# 1           False    False     False  False    False   False       True  1995
# 2           False    False     False  False     True   False      False  1995
# 3           False    False     False   True     True   False      False  1995
# 4           False    False     False  False    False   False      False  1995
# ...           ...      ...       ...    ...      ...     ...        ...   ...
# 9737        False    False     False  False    False   False      False  2017
# 9738        False    False     False  False    False   False      False  2017
# 9739        False    False     False   True    False   False      False  2017
# 9740        False    False     False  False    False   False      False  2018
# 9741        False    False     False  False    False   False      False  1991
#
# [9742 rows x 24 columns]

# %%
#movie[movie['Year']=='NA']
movie.groupby(['Year']).count()
# Out:
#       movieId  title  genres  Animation  Fantasy  IMAX  (no genres listed)  \
# Year
# 1902        1      1       1          1        1     1                   1
# 1903        1      1       1          1        1     1                   1
# 1908        1      1       1          1        1     1                   1
# 1915        1      1       1          1        1     1                   1
# 1916        4      4       4          4        4     4                   4
# ...       ...    ...     ...        ...      ...   ...                 ...
# 2015      274    274     274        274      274   274                 274
# 2016      218    218     218        218      218   218                 218
# 2017      147    147     147        147      147   147                 147
# 2018       41     41      41         41       41    41                  41
# NA         13     13      13         13       13    13                  13
#
#       Crime  Film-Noir  Action  ...  Mystery  Comedy  War  Documentary  \
# Year                            ...
# 1902      1          1       1  ...        1       1    1            1
# 1903      1          1       1  ...        1       1    1            1
# 1908      1          1       1  ...        1       1    1            1
# 1915      1          1       1  ...        1       1    1            1
# 1916      4          4       4  ...        4       4    4            4
# ...     ...        ...     ...  ...      ...     ...  ...          ...
# 2015    274        274     274  ...      274     274  274          274
# 2016    218        218     218  ...      218     218  218          218
# 2017    147        147     147  ...      147     147  147          147
# 2018     41         41      41  ...       41      41   41           41
# NA       13         13      13  ...       13      13   13           13
#
#       Musical  Thriller  Drama  Romance  Horror  Adventure
# Year
# 1902        1         1      1        1       1          1
# 1903        1         1      1        1       1          1
# 1908        1         1      1        1       1          1
# 1915        1         1      1        1       1          1
# 1916        4         4      4        4       4          4
# ...       ...       ...    ...      ...     ...        ...
# 2015      274       274    274      274     274        274
# 2016      218       218    218      218     218        218
# 2017      147       147    147      147     147        147
# 2018       41        41     41       41      41         41
# NA         13        13     13       13      13         13
#
# [107 rows x 23 columns]

# %% [markdown]
# # Q6.(.5 point) Using seaborn, plot a bar plot of average number of movies per year. Do you see any trend?

# %%
# write code here.
moviesPerYear = movie.groupby(['Year']).size().drop("NA").reset_index().rename(columns={0: 'Number of Movies'})
#moviesPerYear
sns.barplot(x = 'Year', y='Number of Movies', data=moviesPerYear).set_title('Average Number of Movies per Year')
plt.xticks(fontsize=5, rotation=70)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q7.(1 point) Using matplotlib, plot total number of movies (cumulative over all the years) for each genre.  Your plot should have proper title, axis labels and legends.

# %%
moviesByGenre = dict()
for genre in unique_genre: 
    moviesByGenre[genre] = int(movie[genre].sum())
moviesByGenre
genres = list(moviesByGenre.keys())
counts = list(moviesByGenre.values())
plt.bar(range(len(moviesByGenre)), counts, tick_label=genres)
plt.title('Total Number of Movies by Genre')
plt.ylabel('Number of Movies')
plt.xlabel('Genre')
plt.xticks(fontsize=8, rotation=70)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Q 8 (.5 point) Build a *movie_title* column containing  the title of the movie. (It should not contain year). Drop the original *title* columns. Display final movie dataFrame.

# %%
# write pandas code here
for i in range(len(movie)):
    text = movie['title'][i]
    text = text.replace(r'\([0-9]{4}\)', "")
    a = re.sub(r'\([0-9]{4}\)', '', text)
    movie.at[i, 'movie_title'] = a

movie.drop(['title'], axis=1, inplace = True)
movie
# Out:
#       movieId                                       genres  Animation  \
# 0           1  Adventure|Animation|Children|Comedy|Fantasy       True
# 1           2                   Adventure|Children|Fantasy      False
# 2           3                               Comedy|Romance      False
# 3           4                         Comedy|Drama|Romance      False
# 4           5                                       Comedy      False
# ...       ...                                          ...        ...
# 9737   193581              Action|Animation|Comedy|Fantasy       True
# 9738   193583                     Animation|Comedy|Fantasy       True
# 9739   193585                                        Drama      False
# 9740   193587                             Action|Animation       True
# 9741   193609                                       Comedy      False
#
#       Fantasy   IMAX  (no genres listed)  Crime  Film-Noir  Action  Children  \
# 0        True  False               False  False      False   False      True
# 1        True  False               False  False      False   False      True
# 2       False  False               False  False      False   False     False
# 3       False  False               False  False      False   False     False
# 4       False  False               False  False      False   False     False
# ...       ...    ...                 ...    ...        ...     ...       ...
# 9737     True  False               False  False      False    True     False
# 9738     True  False               False  False      False   False     False
# 9739    False  False               False  False      False   False     False
# 9740    False  False               False  False      False    True     False
# 9741    False  False               False  False      False   False     False
#
#       ...    War  Documentary  Musical  Thriller  Drama  Romance  Horror  \
# 0     ...  False        False    False     False  False    False   False
# 1     ...  False        False    False     False  False    False   False
# 2     ...  False        False    False     False  False     True   False
# 3     ...  False        False    False     False   True     True   False
# 4     ...  False        False    False     False  False    False   False
# ...   ...    ...          ...      ...       ...    ...      ...     ...
# 9737  ...  False        False    False     False  False    False   False
# 9738  ...  False        False    False     False  False    False   False
# 9739  ...  False        False    False     False   True    False   False
# 9740  ...  False        False    False     False  False    False   False
# 9741  ...  False        False    False     False  False    False   False
#
#       Adventure  Year                          movie_title
# 0          True  1995                           Toy Story
# 1          True  1995                             Jumanji
# 2         False  1995                    Grumpier Old Men
# 3         False  1995                   Waiting to Exhale
# 4         False  1995         Father of the Bride Part II
# ...         ...   ...                                  ...
# 9737      False  2017  Black Butler: Book of the Atlantic
# 9738      False  2017               No Game No Life: Zero
# 9739      False  2017                               Flint
# 9740      False  2018        Bungo Stray Dogs: Dead Apple
# 9741      False  1991        Andrew Dice Clay: Dice Rules
#
# [9742 rows x 24 columns]

# %% [markdown]
# # Q 9(1 point) Using seaborn, plot average number of words in a movie name over the years in different genres. You may choose to make separate plots for each genre or to make a single color coded plot as a function of years. All plots should have proper title, axis labels and legends. Write your observation in no more than 2 lines.

# %%
title_lengths=[]
for i in range(len(movie)): 
    title_lengths.append(len(movie['movie_title'][i].split()))
movie['title_length'] = title_lengths
#movie

# %%
dataDict={}
for genre in list(unique_genre):
    temp_df = movie[movie[genre]==True].groupby(['Year'])['title_length'].mean().reset_index().rename(columns={'title_length': 'avg_title_length'})
    dataDict[genre]=temp_df
#dataDict

# %%
# %matplotlib inline
for genre in list(unique_genre):
    sns.barplot(data=dataDict[genre], x='Year', y='avg_title_length').set_title(f'Average Number of Words in {genre} Movies Over the Years')
    plt.xticks(fontsize=5, rotation=70)
    plt.tight_layout()
    plt.show()
