# %% [markdown]
# # Pandas DataFrame for storing tweet feed (total 12 points)
#
# Creating the following date frame for storing tweets:
#
# - **climate_feed_df** DataFrame for storing tweets
# - **retweeted_status_df** for storing original tweets

# %%
import pandas as pd
import numpy as np
import nltk
import re
import requests
from bs4 import BeautifulSoup as bsp

# %% [markdown]
# The pickle files retweeted_status_df.pkl and climate_feed.pkl should be in the same folder as this notebook.
# If needed, they can also be downloaded by uncommenting the commands below.

# %%
#!wget https://github.com/psnegi/data_science_tools1/raw/master/hws/retweeted_status_df.pkl

# %%
#!wget https://github.com/psnegi/data_science_tools1/raw/master/hws/climate_feed.pkl

# %% [markdown]
# <font color= "red">Click on these links if the above downloads fail. </font>
#
#
# https://github.com/psnegi/data_science_tools1/raw/master/hws/climate_feed.pkl
#
# https://github.com/psnegi/data_science_tools1/raw/master/hws/retweeted_status_df.pkl
#
# Keep these pickle files in the same directory as the notebook

# %%
retweeted_status_df = pd.read_pickle("./retweeted_status_df.pkl")

# %%
retweeted_status_df
# Out:
#       contributors coordinates                      created_at  \
# 0              NaN         NaN                             NaN
# 1              NaN        None  Sat Feb 09 20:27:45 +0000 2019
# 2              NaN        None  Sat Feb 09 23:56:18 +0000 2019
# 3              NaN        None  Sat Feb 09 23:34:27 +0000 2019
# 4              NaN        None  Sat Feb 09 19:07:56 +0000 2019
# ...            ...         ...                             ...
# 9994           NaN        None  Sat Feb 09 20:56:39 +0000 2019
# 9995           NaN        None  Thu Feb 07 20:27:55 +0000 2019
# 9996           NaN        None  Sat Feb 09 18:33:00 +0000 2019
# 9997           NaN        None  Fri Feb 08 22:15:50 +0000 2019
# 9998           NaN        None  Sat Feb 09 20:41:00 +0000 2019
#
#                                                entities extended_entities  \
# 0                                                   NaN               NaN
# 1     {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 2     {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 3     {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 4     {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# ...                                                 ...               ...
# 9994  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 9995  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9996  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 9997  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 9998  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
#
#       favorite_count favorited   geo            id               id_str  ...  \
# 0                NaN       NaN   NaN           NaN                  NaN  ...
# 1               99.0     False  None  1.094332e+18  1094332044052549633  ...
# 2                6.0     False  None  1.094385e+18  1094384528267902977  ...
# 3              190.0     False  None  1.094379e+18  1094379028608438272  ...
# 4             2905.0     False  None  1.094312e+18  1094311957669265408  ...
# ...              ...       ...   ...           ...                  ...  ...
# 9994             1.0     False  None  1.094339e+18  1094339317324017665  ...
# 9995          3491.0     False  None  1.093607e+18  1093607309606076416  ...
# 9996         12586.0     False  None  1.094303e+18  1094303164805799936  ...
# 9997          4249.0     False  None  1.093997e+18  1093996855111966720  ...
# 9998           166.0     False  None  1.094335e+18  1094335377194799104  ...
#
#                                           quoted_status  quoted_status_id  \
# 0                                                   NaN               NaN
# 1                                                   NaN               NaN
# 2     {'favorited': False, 'favorite_count': 2642, '...      1.093999e+18
# 3     {'favorited': False, 'favorite_count': 220, 'i...      1.093932e+18
# 4                                                   NaN               NaN
# ...                                                 ...               ...
# 9994                                                NaN               NaN
# 9995                                                NaN               NaN
# 9996                                                NaN               NaN
# 9997  {'favorited': False, 'favorite_count': 551, 'i...      1.093893e+18
# 9998                                                NaN               NaN
#
#      quoted_status_id_str  retweet_count retweeted scopes  \
# 0                     NaN            NaN       NaN    NaN
# 1                     NaN           81.0     False    NaN
# 2     1093998640392220673            5.0     False    NaN
# 3     1093931686998487040           31.0     False    NaN
# 4                     NaN          599.0     False    NaN
# ...                   ...            ...       ...    ...
# 9994                  NaN            1.0     False    NaN
# 9995                  NaN          482.0     False    NaN
# 9996                  NaN         2801.0     False    NaN
# 9997  1093893115633647616          642.0     False    NaN
# 9998                  NaN           79.0     False    NaN
#
#                                                  source  \
# 0                                                   NaN
# 1     <a href="http://twitter.com" rel="nofollow">Tw...
# 2     <a href="http://twitter.com/download/android" ...
# 3     <a href="http://twitter.com/download/android" ...
# 4     <a href="http://twitter.com/download/iphone" r...
# ...                                                 ...
# 9994  <a href="http://twitter.com/download/android" ...
# 9995  <a href="http://twitter.com/download/android" ...
# 9996  <a href="https://about.twitter.com/products/tw...
# 9997  <a href="https://mobile.twitter.com" rel="nofo...
# 9998  <a href="https://buffer.com" rel="nofollow">Bu...
#
#                                                    text truncated  \
# 0                                                   NaN       NaN
# 1     The National Party declares war on the Glouces...      True
# 2     This is the same idiot who thought\nThe southe...     False
# 3     Communism is Fascism. Fighting Climate Change ...      True
# 4     Unmitigated climate change would literally des...      True
# ...                                                 ...       ...
# 9994  72% of Americans are 'very worried' about clim...     False
# 9995  @JFaurall @MgBenchjeweler @SpeakerPelosi Calif...      True
# 9996  President Trump believes we should listen to f...      True
# 9997  Wait til he hears how much climate change is g...     False
# 9998       Blue marble no more? https://t.co/hFLndZsiBB     False
#
#                                                    user
# 0                                                   NaN
# 1     {'default_profile': False, 'protected': False,...
# 2     {'default_profile': False, 'protected': False,...
# 3     {'default_profile': False, 'protected': False,...
# 4     {'default_profile': True, 'protected': False, ...
# ...                                                 ...
# 9994  {'default_profile': True, 'protected': False, ...
# 9995  {'default_profile': True, 'protected': False, ...
# 9996  {'default_profile': False, 'protected': False,...
# 9997  {'default_profile': False, 'protected': False,...
# 9998  {'default_profile': False, 'protected': False,...
#
# [9999 rows x 30 columns]

# %%
#climate_feed_df.to_pickle("./climate_feed.pkl")
climate_feed_df = pd.read_pickle("./climate_feed.pkl")
climate_feed_df
# Out:
#      contributors coordinates                      created_at  \
# 0            None        None  Sun Feb 10 00:17:31 +0000 2019
# 1            None        None  Sun Feb 10 00:17:30 +0000 2019
# 2            None        None  Sun Feb 10 00:17:26 +0000 2019
# 3            None        None  Sun Feb 10 00:17:24 +0000 2019
# 4            None        None  Sun Feb 10 00:17:23 +0000 2019
# ...           ...         ...                             ...
# 9994         None        None  Sat Feb 09 20:57:54 +0000 2019
# 9995         None        None  Sat Feb 09 20:57:54 +0000 2019
# 9996         None        None  Sat Feb 09 20:57:53 +0000 2019
# 9997         None        None  Sat Feb 09 20:57:51 +0000 2019
# 9998         None        None  Sat Feb 09 20:57:51 +0000 2019
#
#                                                entities extended_entities  \
# 0     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 1     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 2     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 3     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 4     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# ...                                                 ...               ...
# 9994  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9995  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9996  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9997  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9998  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
#
#      favorite_count favorited   geo                   id               id_str  \
# 0                 0     False  None  1094389867499405313  1094389867499405313
# 1                 0     False  None  1094389862193455105  1094389862193455105
# 2                 0     False  None  1094389844078485506  1094389844078485506
# 3                 0     False  None  1094389837522599936  1094389837522599936
# 4                 0     False  None  1094389831419994112  1094389831419994112
# ...             ...       ...   ...                  ...                  ...
# 9994              0     False  None  1094339630500012033  1094339630500012033
# 9995              0     False  None  1094339629107400704  1094339629107400704
# 9996              0     False  None  1094339627316641794  1094339627316641794
# 9997              0     False  None  1094339619569557504  1094339619569557504
# 9998              0     False  None  1094339617581481984  1094339617581481984
#
#       ... quoted_status     quoted_status_id quoted_status_id_str  \
# 0     ...           NaN                  NaN                  NaN
# 1     ...           NaN                  NaN                  NaN
# 2     ...           NaN  1093998640392220673  1093998640392220673
# 3     ...           NaN  1093931686998487040  1093931686998487040
# 4     ...           NaN                  NaN                  NaN
# ...   ...           ...                  ...                  ...
# 9994  ...           NaN                  NaN                  NaN
# 9995  ...           NaN                  NaN                  NaN
# 9996  ...           NaN                  NaN                  NaN
# 9997  ...           NaN  1093893115633647616  1093893115633647616
# 9998  ...           NaN                  NaN                  NaN
#
#      retweet_count retweeted retweeted_status  \
# 0                0     False              NaN
# 1               81     False     1.094332e+18
# 2                5     False     1.094385e+18
# 3               31     False     1.094379e+18
# 4              599     False     1.094312e+18
# ...            ...       ...              ...
# 9994             1     False     1.094339e+18
# 9995           482     False     1.093607e+18
# 9996          2801     False     1.094303e+18
# 9997           642     False     1.093997e+18
# 9998            79     False     1.094335e+18
#
#                                                  source  \
# 0     <a href="http://twitter.com" rel="nofollow">Tw...
# 1     <a href="http://tapbots.com/tweetbot" rel="nof...
# 2     <a href="https://mobile.twitter.com" rel="nofo...
# 3     <a href="http://twitter.com" rel="nofollow">Tw...
# 4     <a href="http://twitter.com/download/android" ...
# ...                                                 ...
# 9994  <a href="http://twitter.com/download/android" ...
# 9995  <a href="http://twitter.com/download/iphone" r...
# 9996  <a href="http://twitter.com/download/android" ...
# 9997  <a href="http://twitter.com/download/iphone" r...
# 9998  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                                    text truncated  \
# 0     .@SteveKingIA says he's unsure about the scien...      True
# 1     RT @RobOakeshott1: The National Party declares...     False
# 2     RT @emilia_suze: This is the same idiot who th...     False
# 3     RT @PrettyBadLefty: Communism is Fascism. Figh...     False
# 4     RT @kenklippenstein: Unmitigated climate chang...     False
# ...                                                 ...       ...
# 9994  RT @fromhello2hello: 72% of Americans are 'ver...     False
# 9995  RT @stuntdaddy_42: @JFaurall @MgBenchjeweler @...     False
# 9996  RT @SenSanders: President Trump believes we sh...     False
# 9997  RT @KateAronoff: Wait til he hears how much cl...     False
# 9998  RT @GeorgeTakei: Blue marble no more? https://...     False
#
#                   user_id
# 0                31476142
# 1               996782298
# 2                45333453
# 3     1020067726532829185
# 4                19889325
# ...                   ...
# 9994   888112320097918976
# 9995           3324836714
# 9996           1487109794
# 9997           4737089913
# 9998             19444003
#
# [9999 rows x 30 columns]

# %% [markdown]
# Here are dtypes for climate_feed_df. We'll work with only
# - entities to extract hashtags
# - retweeted_status in case we need to extract original full tweet
# - truncated
# - text: tweet text
# - created_at
# - user_id
#
# Some of them have wrong datatypes.

# %%
climate_feed_df.dtypes
# Out:
# contributors                  object
# coordinates                   object
# created_at                    object
# entities                      object
# extended_entities             object
# favorite_count                object
# favorited                     object
# geo                           object
# id                            object
# id_str                        object
# in_reply_to_screen_name       object
# in_reply_to_status_id         object
# in_reply_to_status_id_str     object
# in_reply_to_user_id           object
# in_reply_to_user_id_str       object
# is_quote_status               object
# lang                          object
# metadata                      object
# place                         object
# possibly_sensitive            object
# quoted_status                 object
# quoted_status_id              object
# quoted_status_id_str          object
# retweet_count                 object
# retweeted                     object
# retweeted_status             float64
# source                        object
# text                          object
# truncated                     object
# user_id                        int64
# dtype: object

# %% [markdown]
# # Q1 (points .5) Replace None with nan in climate_feed_df. Also display some random rows.

# %%
# write code here
climate_feed_df.replace("None", "NaN")
# Out:
#      contributors coordinates                      created_at  \
# 0             NaN         NaN  Sun Feb 10 00:17:31 +0000 2019
# 1             NaN         NaN  Sun Feb 10 00:17:30 +0000 2019
# 2             NaN         NaN  Sun Feb 10 00:17:26 +0000 2019
# 3             NaN         NaN  Sun Feb 10 00:17:24 +0000 2019
# 4             NaN         NaN  Sun Feb 10 00:17:23 +0000 2019
# ...           ...         ...                             ...
# 9994          NaN         NaN  Sat Feb 09 20:57:54 +0000 2019
# 9995          NaN         NaN  Sat Feb 09 20:57:54 +0000 2019
# 9996          NaN         NaN  Sat Feb 09 20:57:53 +0000 2019
# 9997          NaN         NaN  Sat Feb 09 20:57:51 +0000 2019
# 9998          NaN         NaN  Sat Feb 09 20:57:51 +0000 2019
#
#                                                entities extended_entities  \
# 0     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 1     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 2     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 3     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 4     {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# ...                                                 ...               ...
# 9994  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9995  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9996  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9997  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 9998  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
#
#      favorite_count favorited  geo                   id               id_str  \
# 0                 0     False  NaN  1094389867499405313  1094389867499405313
# 1                 0     False  NaN  1094389862193455105  1094389862193455105
# 2                 0     False  NaN  1094389844078485506  1094389844078485506
# 3                 0     False  NaN  1094389837522599936  1094389837522599936
# 4                 0     False  NaN  1094389831419994112  1094389831419994112
# ...             ...       ...  ...                  ...                  ...
# 9994              0     False  NaN  1094339630500012033  1094339630500012033
# 9995              0     False  NaN  1094339629107400704  1094339629107400704
# 9996              0     False  NaN  1094339627316641794  1094339627316641794
# 9997              0     False  NaN  1094339619569557504  1094339619569557504
# 9998              0     False  NaN  1094339617581481984  1094339617581481984
#
#       ... quoted_status     quoted_status_id quoted_status_id_str  \
# 0     ...           NaN                  NaN                  NaN
# 1     ...           NaN                  NaN                  NaN
# 2     ...           NaN  1093998640392220673  1093998640392220673
# 3     ...           NaN  1093931686998487040  1093931686998487040
# 4     ...           NaN                  NaN                  NaN
# ...   ...           ...                  ...                  ...
# 9994  ...           NaN                  NaN                  NaN
# 9995  ...           NaN                  NaN                  NaN
# 9996  ...           NaN                  NaN                  NaN
# 9997  ...           NaN  1093893115633647616  1093893115633647616
# 9998  ...           NaN                  NaN                  NaN
#
#      retweet_count retweeted retweeted_status  \
# 0                0     False              NaN
# 1               81     False     1.094332e+18
# 2                5     False     1.094385e+18
# 3               31     False     1.094379e+18
# 4              599     False     1.094312e+18
# ...            ...       ...              ...
# 9994             1     False     1.094339e+18
# 9995           482     False     1.093607e+18
# 9996          2801     False     1.094303e+18
# 9997           642     False     1.093997e+18
# 9998            79     False     1.094335e+18
#
#                                                  source  \
# 0     <a href="http://twitter.com" rel="nofollow">Tw...
# 1     <a href="http://tapbots.com/tweetbot" rel="nof...
# 2     <a href="https://mobile.twitter.com" rel="nofo...
# 3     <a href="http://twitter.com" rel="nofollow">Tw...
# 4     <a href="http://twitter.com/download/android" ...
# ...                                                 ...
# 9994  <a href="http://twitter.com/download/android" ...
# 9995  <a href="http://twitter.com/download/iphone" r...
# 9996  <a href="http://twitter.com/download/android" ...
# 9997  <a href="http://twitter.com/download/iphone" r...
# 9998  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                                    text truncated  \
# 0     .@SteveKingIA says he's unsure about the scien...      True
# 1     RT @RobOakeshott1: The National Party declares...     False
# 2     RT @emilia_suze: This is the same idiot who th...     False
# 3     RT @PrettyBadLefty: Communism is Fascism. Figh...     False
# 4     RT @kenklippenstein: Unmitigated climate chang...     False
# ...                                                 ...       ...
# 9994  RT @fromhello2hello: 72% of Americans are 'ver...     False
# 9995  RT @stuntdaddy_42: @JFaurall @MgBenchjeweler @...     False
# 9996  RT @SenSanders: President Trump believes we sh...     False
# 9997  RT @KateAronoff: Wait til he hears how much cl...     False
# 9998  RT @GeorgeTakei: Blue marble no more? https://...     False
#
#                   user_id
# 0                31476142
# 1               996782298
# 2                45333453
# 3     1020067726532829185
# 4                19889325
# ...                   ...
# 9994   888112320097918976
# 9995           3324836714
# 9996           1487109794
# 9997           4737089913
# 9998             19444003
#
# [9999 rows x 30 columns]

# %% [markdown]
# Working with only selected attributes.

# %%
climate_feed_df = climate_feed_df[['created_at', 'entities','retweeted_status', 'truncated', 'user_id', 'text' ]].copy()

# %%
climate_feed_df.sample(10)
# Out:
#                           created_at  \
# 6349  Sat Feb 09 22:09:11 +0000 2019
# 8677  Sat Feb 09 21:22:41 +0000 2019
# 2732  Sat Feb 09 23:26:02 +0000 2019
# 7219  Sat Feb 09 21:51:31 +0000 2019
# 5092  Sat Feb 09 22:34:08 +0000 2019
# 5490  Sat Feb 09 22:26:39 +0000 2019
# 6908  Sat Feb 09 21:58:23 +0000 2019
# 2015  Sat Feb 09 23:39:01 +0000 2019
# 548   Sun Feb 10 00:06:17 +0000 2019
# 2117  Sat Feb 09 23:36:51 +0000 2019
#
#                                                entities  retweeted_status  \
# 6349  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094212e+18
# 8677  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094335e+18
# 2732  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094376e+18
# 7219  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094303e+18
# 5092  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094300e+18
# 5490  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094062e+18
# 6908  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094303e+18
# 2015  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094379e+18
# 548   {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
# 2117  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
#
#      truncated              user_id  \
# 6349     False            531192647
# 8677     False             27927742
# 2732     False   954835118073532419
# 7219     False           3959718724
# 5092     False           2950567428
# 5490     False   836467701002473472
# 6908     False   975395003231973376
# 2015     False  1006751093311844353
# 548      False           2552688877
# 2117      True             17111359
#
#                                                    text
# 6349  RT @marklevinshow: The insane Democrat Left.  ...
# 8677  RT @SiddonsDan: “Does God’s creation not inclu...
# 2732  RT @drawandstrike: THIS is why on almost every...
# 7219  RT @SenSanders: President Trump believes we sh...
# 5092  RT @alexessabuda: friendly reminder that you’r...
# 5490  RT @ericswalwell: Climate change is real, and ...
# 6908  RT @SenSanders: President Trump believes we sh...
# 2015  RT @Jordan_Sather_: 🤣🤣🤣\n\nQuite the crock of ...
# 548   Climate change really is wild. https://t.co/wE...
# 2117  Bear in mind that A CHARLIE BROWN CHRISTMAS es...

# %% [markdown]
# # Q2 (points .5 =.25+.25) convert
# - created_at to date time type
# - truncated to bool type.

# %%
climate_feed_df['created_at'] = pd.to_datetime(climate_feed_df['created_at'])
climate_feed_df["truncated"] = np.where(climate_feed_df["truncated"] == "True", True, False)

# %% [markdown]
# Checking datatype again

# %%
climate_feed_df.dtypes
# Out:
# created_at          datetime64[ns, UTC]
# entities                         object
# retweeted_status                float64
# truncated                          bool
# user_id                           int64
# text                             object
# dtype: object

# %% [markdown]
# # Q3(points .5) In climate_feed_df, calculate the number of NAN values in various columns

# %%
climate_feed_df.isna().sum().sum()
# Out:
# 2690

# %% [markdown]
# We'll use **ast** module to parse string to python dictionary

# %% [markdown]
# # Q4(points 1=.5+.5) Using *ast* module  convert entities to python dictionary. This dictionary should contain hashtags and user_mentions
#  - Create a column named hashtags. Values in this columns should be comma separated values of **text** attribute in **hashtags**  value.
#  - Create a column named user_mentions. Values in this columns should be command separated values of **name** attribute in **user_mentions** values.

# %%
import ast

climate_feed_df["entities"] = climate_feed_df["entities"].apply(lambda x: ast.literal_eval(x))

# %%
hashes = [k['hashtags'] for k in climate_feed_df["entities"]]
mentions = [k['user_mentions'] for k in climate_feed_df["entities"]]

climate_feed_df['hashtags'] = hashes
climate_feed_df['user_mentions'] = mentions

# %%
for i in range(len(climate_feed_df)):
    hashValues = climate_feed_df.loc[i,'hashtags']
    if hashValues:
        climate_feed_df.at[i,'hashtags'] = ','.join(map(str, hashValues))
    else:
        climate_feed_df.at[i,'hashtags'] = None
        
    users = climate_feed_df.loc[i,'user_mentions']
    if users:
        names = []
        for k in users:
            name = k.get('name')
            names.append(name)
            climate_feed_df.at[i,'user_mentions'] = ','.join(map(str, names))
    else:
        climate_feed_df.at[i,'user_mentions'] = None
        
climate_feed_df.head(n=10)
# Out:
#                  created_at  \
# 0 2019-02-10 00:17:31+00:00
# 1 2019-02-10 00:17:30+00:00
# 2 2019-02-10 00:17:26+00:00
# 3 2019-02-10 00:17:24+00:00
# 4 2019-02-10 00:17:23+00:00
# 5 2019-02-10 00:17:21+00:00
# 6 2019-02-10 00:17:21+00:00
# 7 2019-02-10 00:17:20+00:00
# 8 2019-02-10 00:17:19+00:00
# 9 2019-02-10 00:17:18+00:00
#
#                                             entities  retweeted_status  \
# 0  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 1  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094332e+18
# 2  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094385e+18
# 3  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094379e+18
# 4  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094312e+18
# 5  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094381e+18
# 6  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094276e+18
# 7  {'hashtags': [], 'user_mentions': [{'id_str': ...               NaN
# 8  {'hashtags': [], 'user_mentions': [{'id_str': ...      1.094335e+18
# 9  {'hashtags': [], 'user_mentions': [], 'urls': ...               NaN
#
#    truncated              user_id  \
# 0       True             31476142
# 1      False            996782298
# 2      False             45333453
# 3      False  1020067726532829185
# 4      False             19889325
# 5      False             16909343
# 6      False   908017796881240064
# 7       True  1065520951150800896
# 8      False            943754900
# 9      False             64454244
#
#                                                 text hashtags  \
# 0  .@SteveKingIA says he's unsure about the scien...     None
# 1  RT @RobOakeshott1: The National Party declares...     None
# 2  RT @emilia_suze: This is the same idiot who th...     None
# 3  RT @PrettyBadLefty: Communism is Fascism. Figh...     None
# 4  RT @kenklippenstein: Unmitigated climate chang...     None
# 5  RT @ChrisJZullo: @realDonaldTrump Climate chan...     None
# 6  RT @alexanderbruz: Happy Saturday! Friendly re...     None
# 7  @kantarjiev @gsheyner Yes, this downtown parki...     None
# 8  RT @GeorgeTakei: Blue marble no more? https://...     None
# 9  Coming up next on CCTV's government channel (C...     None
#
#                             user_mentions
# 0                              Steve King
# 1                           Rob Oakeshott
# 2                          Suze Michelini
# 3                           Chad Vigorous
# 4                        Ken Klippenstein
# 5  ♻️🇺🇸 Christopher Zullo,Donald J. Trump
# 6                    Alexander Bruesewitz
# 7        Chris Kantarjiev,Gennady Sheyner
# 8                            George Takei
# 9                                    None

# %% [markdown]
# # Cleaning tweets
#
# Let's see some random tweets

# %%
tweet_length= 280
pd.set_option('max_colwidth', 2*tweet_length)
climate_feed_df['text'].sample(100)
# Out:
# 175           @realDonaldTrump As a meteorologist I can tell you that man-made global warming/climate change is pure BS. Change o… https://t.co/E1yrdxtMjW
# 5955      RT @ImranKhanPTI: We are launching our #Plant4Pakistan programme &amp; reclaiming mafia encroached land, converting it into forests and wild li…
# 5235    RT @michaeldaleyMP: A government led by me will take climate change seriously &amp; support renewable energy across NSW.\n\nLabor will help an ex…
# 2255          RT @tessmajors1: Do you ever just get (whips) absolutely terrified (nae naes) of climate change driven by (pipes it up) excessive consumeri…
# 9251        RT @ByRosenberg: God bless the climate reporters who painstainkingly write explainers on why winter still exists despite climate change\n\n"W…
#                                                                                ...
# 4259          RT @_Oliver_Yates: If only Abbott could fight as hard for the safety of our country from the impacts of climate change, as he is fighting f…
# 6129          RT @brutamerica: Look what 16-year old @GretaThunberg has started. An estimated 10,000 students marched through The Hague, Netherlands toda…
# 104                                  RT @likeagirlinc: Global temperatures in 2018 fourth hottest on record, scientists confirm\n\nhttps://t.co/6C92aPYkV2
# 2453                                           @silveraa @realDonaldTrump Ask him about his UK golf courses and flood barriers.\n\nhttps://t.co/MdEzIVdSnM
# 5518     RT @olivier_patti: @surrenderPOTUS \n@B52Malmet \n@northeast_mama \n@jakki2004 @DrDinD \n@LunaLuvgood2017 \n@Lady_Star_Gem \n@TTrueman @DemWrite…
# Name: text, Length: 100, dtype: object

# %% [markdown]
# **Example of tweet not truncated**

# %%
climate_feed_df['text'].loc[3929]
# Out:
# 'Fighting climate change without nuclear is a fool’s errand. https://t.co/KPSCk6fjsa'

# %% [markdown]
# **Exampe of tweet truncated**

# %%
climate_feed_df['text'].loc[3928]
# Out:
# 'RT @_Oliver_Yates: If only Abbott could fight as hard for the safety of our country from the impacts of climate change, as he is fighting f…'

# %% [markdown]
# Truncated tweet has three horizontal ellipses in it. One can check retweeted_status values and
# use it got the the original tweet text

# %%
climate_feed_df.retweeted_status.loc[3928]
# Out:
# 1.0943594112863928e+18

# %%
retweeted_status_df[retweeted_status_df.id == climate_feed_df.retweeted_status.loc[3928]].text.iloc[0]
# Out:
# 'If only Abbott could fight as hard for the safety of our country from the impacts of climate change, as he is fight… https://t.co/OJlsDeFoNA'

# %% [markdown]
# There is url above tweet. We can use **requests** to get the complete text.

# %% [markdown]
# # Q5(3.5 points, 1 for the use of requests and text extraction from right html element+.5+1+1 for the rest.) Perform following activities for creating a new original_tweet_text field in climate_feed_df.
#
# Option 1. This question frequently presents a challenge to students. If needed, please use the provided pickle file.
# Just uncomment the following cell to import the dataframe.
#
# Option 2. Use twitter API. For this you will need to look at hw 4 to set up the connection and use the "2/tweets/{id}" endpoint.
#
# Either option will work. You will still need to do the cleaning portion of the question for either option you choose.
#
# This is also the documentation link for the api call:
# https://developer.twitter.com/en/docs/twitter-api/tweets/lookup/api-reference/get-tweets-id
#
# - If  climate_feed_df has a valid retweeted_status(**it is an id of the record in retweeted_status_df** ), then use retweeted_status_df to get the original text(**retweeted_status_df.text**) otherwise use None(**Ignore the value of climate_feed_df.truncated field for this activity.**).
#     + If retweeted_status_df.text has a URL(like https://t.co/RKyppIS5c9 ), use it to get complete text from right html element.
#
#     *If you have a way to figure out that one is not supposed to web scrap this URL don't scrap it.*
#
# - Create a new field named **original_tweet_text** in climate_feed_df to store the text extracted from URL(use None if requests to URL fails or any other issues.). Use retweeted_status_df.text if there was no
#  URL.
# - From  newly original_tweet_text field remove
#     - one or more \n with .(dot)
#     - any url(http, https)
#     - @user, @user:
#
# *Note that as you will be making a lot of requests call(I/O bound calls), this portion of code can be slow. you may want to test your code on a small number of records first.*

# %%
import pickle
with open('q5_dataframe.pkl', 'rb') as f:
    climate_feed_df = pickle.loads(f.read())
climate_feed_df.head()
# Out:
#            created_at  \
# 0 2019-02-10 00:17:31
# 1 2019-02-10 00:17:30
# 2 2019-02-10 00:17:26
# 3 2019-02-10 00:17:24
# 4 2019-02-10 00:17:23
#
#                                                                                                                                                                                                                                                                                                                                                                                       entities  \
# 0                                {'hashtags': [], 'user_mentions': [{'id_str': '48117116', 'name': 'Steve King', 'screen_name': 'SteveKingIA', 'indices': [1, 13], 'id': 48117116}], 'urls': [{'indices': [117, 140], 'url': 'https://t.co/J1CcrQZkB2', 'display_url': 'twitter.com/i/web/status/1…', 'expanded_url': 'https://twitter.com/i/web/status/1094389867499405313'}], 'symbols': []}
# 1                                                                                                                                                                                                          {'hashtags': [], 'user_mentions': [{'id_str': '16777464', 'name': 'Rob Oakeshott', 'screen_name': 'RobOakeshott1', 'indices': [3, 17], 'id': 16777464}], 'urls': [], 'symbols': []}
# 2  {'hashtags': [], 'user_mentions': [{'id_str': '850130990706151428', 'name': 'Suze Michelini', 'screen_name': 'emilia_suze', 'indices': [3, 15], 'id': 850130990706151428}], 'urls': [{'indices': [105, 128], 'url': 'https://t.co/HWjCJGhQIx', 'display_url': 'twitter.com/LeoDiCaprio/st…', 'expanded_url': 'https://twitter.com/LeoDiCaprio/status/1093998640392220673'}], 'symbols': []}
# 3                                                                                                                                                                                     {'hashtags': [], 'user_mentions': [{'id_str': '753005970318626816', 'name': 'Chad Vigorous', 'screen_name': 'PrettyBadLefty', 'indices': [3, 18], 'id': 753005970318626816}], 'urls': [], 'symbols': []}
# 4                                                                                                                                                                                                 {'hashtags': [], 'user_mentions': [{'id_str': '1634248890', 'name': 'Ken Klippenstein', 'screen_name': 'kenklippenstein', 'indices': [3, 19], 'id': 1634248890}], 'urls': [], 'symbols': []}
#
#    retweeted_status  truncated              user_id  \
# 0               NaN       True             31476142
# 1      1.094332e+18       True            996782298
# 2      1.094385e+18       True             45333453
# 3      1.094379e+18       True  1020067726532829185
# 4      1.094312e+18       True             19889325
#
#                                                                                                                                            text  \
# 0  .@SteveKingIA says he's unsure about the science of climate change. But you don’t need to be a scientist to take ac… https://t.co/J1CcrQZkB2
# 1   RT @RobOakeshott1: The National Party declares war on the Gloucester community because they stood up for themselves and won. Remember, the…
# 2             RT @emilia_suze: This is the same idiot who thought\nThe southern Alberta chinook was climate change lol. https://t.co/HWjCJGhQIx
# 3  RT @PrettyBadLefty: Communism is Fascism. Fighting Climate Change will Kill millions. Apparently, you're just allowed to say shit on MSNBC.…
# 4  RT @kenklippenstein: Unmitigated climate change would literally destroy civilization but doing something about it might increase the defici…
#
#   hashtags     user_mentions  \
# 0     None        Steve King
# 1     None     Rob Oakeshott
# 2     None    Suze Michelini
# 3     None     Chad Vigorous
# 4     None  Ken Klippenstein
#
#                                                                                                                             original_tweet_text  \
# 0                                                                                                                                          None
# 1  The National Party declares war on the Gloucester community because they stood up for themselves and won. Remember,… https://t.co/G0PqMIEUMV
# 2                              This is the same idiot who thought\nThe southern Alberta chinook was climate change lol. https://t.co/HWjCJGhQIx
# 3  Communism is Fascism. Fighting Climate Change will Kill millions. Apparently, you're just allowed to say shit on MS… https://t.co/2asxrk5Fqd
# 4  Unmitigated climate change would literally destroy civilization but doing something about it might increase the def… https://t.co/1J7lLUkYyY
#
#   original_tweet_id_str
# 0                  None
# 1   1094332044052549633
# 2   1094384528267902977
# 3   1094379028608438272
# 4   1094311957669265408

# %%
import re

for i in range(len(climate_feed_df)):
    text = climate_feed_df['original_tweet_text'][i]
    if text:
        text = text.replace('\n',".")
        text = text.replace('\t', "")
        a = re.sub(r'http\S+|RT|@\S+', '', text)
        climate_feed_df.at[i, 'original_tweet_text'] = a
    else:
        climate_feed_df.at[i, 'original_tweet_text'] = None

climate_feed_df
# Out:
#               created_at  \
# 0    2019-02-10 00:17:31
# 1    2019-02-10 00:17:30
# 2    2019-02-10 00:17:26
# 3    2019-02-10 00:17:24
# 4    2019-02-10 00:17:23
# ...                  ...
# 9994 2019-02-09 20:57:54
# 9995 2019-02-09 20:57:54
# 9996 2019-02-09 20:57:53
# 9997 2019-02-09 20:57:51
# 9998 2019-02-09 20:57:51
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              entities  \
# 0                                                                                                                                                                                                                       {'hashtags': [], 'user_mentions': [{'id_str': '48117116', 'name': 'Steve King', 'screen_name': 'SteveKingIA', 'indices': [1, 13], 'id': 48117116}], 'urls': [{'indices': [117, 140], 'url': 'https://t.co/J1CcrQZkB2', 'display_url': 'twitter.com/i/web/status/1…', 'expanded_url': 'https://twitter.com/i/web/status/1094389867499405313'}], 'symbols': []}
# 1                                                                                                                                                                                                                                                                                                                                                                                                 {'hashtags': [], 'user_mentions': [{'id_str': '16777464', 'name': 'Rob Oakeshott', 'screen_name': 'RobOakeshott1', 'indices': [3, 17], 'id': 16777464}], 'urls': [], 'symbols': []}
# 2                                                                                                                                                                                         {'hashtags': [], 'user_mentions': [{'id_str': '850130990706151428', 'name': 'Suze Michelini', 'screen_name': 'emilia_suze', 'indices': [3, 15], 'id': 850130990706151428}], 'urls': [{'indices': [105, 128], 'url': 'https://t.co/HWjCJGhQIx', 'display_url': 'twitter.com/LeoDiCaprio/st…', 'expanded_url': 'https://twitter.com/LeoDiCaprio/status/1093998640392220673'}], 'symbols': []}
# 3                                                                                                                                                                                                                                                                                                                                                                            {'hashtags': [], 'user_mentions': [{'id_str': '753005970318626816', 'name': 'Chad Vigorous', 'screen_name': 'PrettyBadLefty', 'indices': [3, 18], 'id': 753005970318626816}], 'urls': [], 'symbols': []}
# 4                                                                                                                                                                                                                                                                                                                                                                                        {'hashtags': [], 'user_mentions': [{'id_str': '1634248890', 'name': 'Ken Klippenstein', 'screen_name': 'kenklippenstein', 'indices': [3, 19], 'id': 1634248890}], 'urls': [], 'symbols': []}
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 9994                                                                                                                                      {'hashtags': [], 'user_mentions': [{'id_str': '1073261955216039937', 'name': 'fromhello2hello', 'screen_name': 'fromhello2hello', 'indices': [3, 19], 'id': 1073261955216039937}], 'urls': [{'indices': [78, 101], 'url': 'https://t.co/P1X5jfuUQC', 'display_url': 'treehugger.com/climate-change…', 'expanded_url': 'https://www.treehugger.com/climate-change/72-americans-are-very-worried-about-climate-change.html'}], 'symbols': []}
# 9995  {'hashtags': [], 'user_mentions': [{'id_str': '1082006962995429383', 'name': 'stuntdaddy_42', 'screen_name': 'stuntdaddy_42', 'indices': [3, 17], 'id': 1082006962995429383}, {'id_str': '2497547378', 'name': 'Justice Faurall', 'screen_name': 'JFaurall', 'indices': [19, 28], 'id': 2497547378}, {'id_str': '3073664870', 'name': 'Michael Shelton', 'screen_name': 'MgBenchjeweler', 'indices': [29, 44], 'id': 3073664870}, {'id_str': '15764644', 'name': 'Nancy Pelosi', 'screen_name': 'SpeakerPelosi', 'indices': [45, 59], 'id': 15764644}], 'urls': [], 'symbols...
# 9996                                                                                                                                                                                                                                                                                                                                                                                                {'hashtags': [], 'user_mentions': [{'id_str': '29442313', 'name': 'Bernie Sanders', 'screen_name': 'SenSanders', 'indices': [3, 14], 'id': 29442313}], 'urls': [], 'symbols': []}
# 9997                                                                                                                                                                                                               {'hashtags': [], 'user_mentions': [{'id_str': '637196658', 'name': 'Kate Aronoff', 'screen_name': 'KateAronoff', 'indices': [3, 15], 'id': 637196658}], 'urls': [{'indices': [73, 96], 'url': 'https://t.co/P6znQNsbLH', 'display_url': 'twitter.com/business/statu…', 'expanded_url': 'https://twitter.com/business/status/1093893115633647616'}], 'symbols': []}
# 9998                                                                                                                                                                                                                                                                  {'hashtags': [], 'user_mentions': [{'id_str': '237845487', 'name': 'George Takei', 'screen_name': 'GeorgeTakei', 'indices': [3, 15], 'id': 237845487}], 'urls': [{'indices': [38, 61], 'url': 'https://t.co/hFLndZsiBB', 'display_url': 'po.st/P5AgAW', 'expanded_url': 'http://po.st/P5AgAW'}], 'symbols': []}
#
#       retweeted_status  truncated              user_id  \
# 0                  NaN       True             31476142
# 1         1.094332e+18       True            996782298
# 2         1.094385e+18       True             45333453
# 3         1.094379e+18       True  1020067726532829185
# 4         1.094312e+18       True             19889325
# ...                ...        ...                  ...
# 9994      1.094339e+18       True   888112320097918976
# 9995      1.093607e+18       True           3324836714
# 9996      1.094303e+18       True           1487109794
# 9997      1.093997e+18       True           4737089913
# 9998      1.094335e+18       True             19444003
#
#                                                                                                                                                 text  \
# 0       .@SteveKingIA says he's unsure about the science of climate change. But you don’t need to be a scientist to take ac… https://t.co/J1CcrQZkB2
# 1        RT @RobOakeshott1: The National Party declares war on the Gloucester community because they stood up for themselves and won. Remember, the…
# 2                  RT @emilia_suze: This is the same idiot who thought\nThe southern Alberta chinook was climate change lol. https://t.co/HWjCJGhQIx
# 3       RT @PrettyBadLefty: Communism is Fascism. Fighting Climate Change will Kill millions. Apparently, you're just allowed to say shit on MSNBC.…
# 4       RT @kenklippenstein: Unmitigated climate change would literally destroy civilization but doing something about it might increase the defici…
# ...                                                                                                                                              ...
# 9994                                           RT @fromhello2hello: 72% of Americans are 'very worried' about climate change https://t.co/P1X5jfuUQC
# 9995     RT @stuntdaddy_42: @JFaurall @MgBenchjeweler @SpeakerPelosi California was given hundreds of millions of dollars over the years to prevent…
# 9996  RT @SenSanders: President Trump believes we should listen to fossil fuel executives and ignore climate change. \n\nI believe we should listen…
# 9997                                                RT @KateAronoff: Wait til he hears how much climate change is gonna cost https://t.co/P6znQNsbLH
# 9998                                                                                   RT @GeorgeTakei: Blue marble no more? https://t.co/hFLndZsiBB
#
#      hashtags                                               user_mentions  \
# 0        None                                                  Steve King
# 1        None                                               Rob Oakeshott
# 2        None                                              Suze Michelini
# 3        None                                               Chad Vigorous
# 4        None                                            Ken Klippenstein
# ...       ...                                                         ...
# 9994     None                                             fromhello2hello
# 9995     None  stuntdaddy_42,Justice Faurall,Michael Shelton,Nancy Pelosi
# 9996     None                                              Bernie Sanders
# 9997     None                                                Kate Aronoff
# 9998     None                                                George Takei
#
#                                                                                                         original_tweet_text  \
# 0                                                                                                                      None
# 1     The National Party declares war on the Gloucester community because they stood up for themselves and won. Remember,…
# 2                                  This is the same idiot who thought.The southern Alberta chinook was climate change lol.
# 3     Communism is Fascism. Fighting Climate Change will Kill millions. Apparently, you're just allowed to say shit on MS…
# 4     Unmitigated climate change would literally destroy civilization but doing something about it might increase the def…
# ...                                                                                                                     ...
# 9994                                                              72% of Americans are 'very worried' about climate change
# 9995                                           California was given hundreds of millions of dollars over the years to pre…
# 9996  President Trump believes we should listen to fossil fuel executives and ignore climate change. ..I believe we shoul…
# 9997                                                               Wait til he hears how much climate change is gonna cost
# 9998                                                                                                  Blue marble no more?
#
#      original_tweet_id_str
# 0                     None
# 1      1094332044052549633
# 2      1094384528267902977
# 3      1094379028608438272
# 4      1094311957669265408
# ...                    ...
# 9994   1094339317324017665
# 9995   1093607309606076416
# 9996   1094303164805799936
# 9997   1093996855111966720
# 9998   1094335377194799104
#
# [9999 rows x 10 columns]

# %% [markdown]
# # Q 6(point 1= .5+.5) Remove all the references  of RT and  @user: or @user, and url in climate_feed_df text attribute.

# %%
for i in range(len(climate_feed_df)):
    text = climate_feed_df['text'][i]
    a = re.sub(r'http\S+|RT|@\S+', '', text)
    climate_feed_df.at[i, 'text'] = a

climate_feed_df
# Out:
#               created_at  \
# 0    2019-02-10 00:17:31
# 1    2019-02-10 00:17:30
# 2    2019-02-10 00:17:26
# 3    2019-02-10 00:17:24
# 4    2019-02-10 00:17:23
# ...                  ...
# 9994 2019-02-09 20:57:54
# 9995 2019-02-09 20:57:54
# 9996 2019-02-09 20:57:53
# 9997 2019-02-09 20:57:51
# 9998 2019-02-09 20:57:51
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              entities  \
# 0                                                                                                                                                                                                                       {'hashtags': [], 'user_mentions': [{'id_str': '48117116', 'name': 'Steve King', 'screen_name': 'SteveKingIA', 'indices': [1, 13], 'id': 48117116}], 'urls': [{'indices': [117, 140], 'url': 'https://t.co/J1CcrQZkB2', 'display_url': 'twitter.com/i/web/status/1…', 'expanded_url': 'https://twitter.com/i/web/status/1094389867499405313'}], 'symbols': []}
# 1                                                                                                                                                                                                                                                                                                                                                                                                 {'hashtags': [], 'user_mentions': [{'id_str': '16777464', 'name': 'Rob Oakeshott', 'screen_name': 'RobOakeshott1', 'indices': [3, 17], 'id': 16777464}], 'urls': [], 'symbols': []}
# 2                                                                                                                                                                                         {'hashtags': [], 'user_mentions': [{'id_str': '850130990706151428', 'name': 'Suze Michelini', 'screen_name': 'emilia_suze', 'indices': [3, 15], 'id': 850130990706151428}], 'urls': [{'indices': [105, 128], 'url': 'https://t.co/HWjCJGhQIx', 'display_url': 'twitter.com/LeoDiCaprio/st…', 'expanded_url': 'https://twitter.com/LeoDiCaprio/status/1093998640392220673'}], 'symbols': []}
# 3                                                                                                                                                                                                                                                                                                                                                                            {'hashtags': [], 'user_mentions': [{'id_str': '753005970318626816', 'name': 'Chad Vigorous', 'screen_name': 'PrettyBadLefty', 'indices': [3, 18], 'id': 753005970318626816}], 'urls': [], 'symbols': []}
# 4                                                                                                                                                                                                                                                                                                                                                                                        {'hashtags': [], 'user_mentions': [{'id_str': '1634248890', 'name': 'Ken Klippenstein', 'screen_name': 'kenklippenstein', 'indices': [3, 19], 'id': 1634248890}], 'urls': [], 'symbols': []}
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 9994                                                                                                                                      {'hashtags': [], 'user_mentions': [{'id_str': '1073261955216039937', 'name': 'fromhello2hello', 'screen_name': 'fromhello2hello', 'indices': [3, 19], 'id': 1073261955216039937}], 'urls': [{'indices': [78, 101], 'url': 'https://t.co/P1X5jfuUQC', 'display_url': 'treehugger.com/climate-change…', 'expanded_url': 'https://www.treehugger.com/climate-change/72-americans-are-very-worried-about-climate-change.html'}], 'symbols': []}
# 9995  {'hashtags': [], 'user_mentions': [{'id_str': '1082006962995429383', 'name': 'stuntdaddy_42', 'screen_name': 'stuntdaddy_42', 'indices': [3, 17], 'id': 1082006962995429383}, {'id_str': '2497547378', 'name': 'Justice Faurall', 'screen_name': 'JFaurall', 'indices': [19, 28], 'id': 2497547378}, {'id_str': '3073664870', 'name': 'Michael Shelton', 'screen_name': 'MgBenchjeweler', 'indices': [29, 44], 'id': 3073664870}, {'id_str': '15764644', 'name': 'Nancy Pelosi', 'screen_name': 'SpeakerPelosi', 'indices': [45, 59], 'id': 15764644}], 'urls': [], 'symbols...
# 9996                                                                                                                                                                                                                                                                                                                                                                                                {'hashtags': [], 'user_mentions': [{'id_str': '29442313', 'name': 'Bernie Sanders', 'screen_name': 'SenSanders', 'indices': [3, 14], 'id': 29442313}], 'urls': [], 'symbols': []}
# 9997                                                                                                                                                                                                               {'hashtags': [], 'user_mentions': [{'id_str': '637196658', 'name': 'Kate Aronoff', 'screen_name': 'KateAronoff', 'indices': [3, 15], 'id': 637196658}], 'urls': [{'indices': [73, 96], 'url': 'https://t.co/P6znQNsbLH', 'display_url': 'twitter.com/business/statu…', 'expanded_url': 'https://twitter.com/business/status/1093893115633647616'}], 'symbols': []}
# 9998                                                                                                                                                                                                                                                                  {'hashtags': [], 'user_mentions': [{'id_str': '237845487', 'name': 'George Takei', 'screen_name': 'GeorgeTakei', 'indices': [3, 15], 'id': 237845487}], 'urls': [{'indices': [38, 61], 'url': 'https://t.co/hFLndZsiBB', 'display_url': 'po.st/P5AgAW', 'expanded_url': 'http://po.st/P5AgAW'}], 'symbols': []}
#
#       retweeted_status  truncated              user_id  \
# 0                  NaN       True             31476142
# 1         1.094332e+18       True            996782298
# 2         1.094385e+18       True             45333453
# 3         1.094379e+18       True  1020067726532829185
# 4         1.094312e+18       True             19889325
# ...                ...        ...                  ...
# 9994      1.094339e+18       True   888112320097918976
# 9995      1.093607e+18       True           3324836714
# 9996      1.094303e+18       True           1487109794
# 9997      1.093997e+18       True           4737089913
# 9998      1.094335e+18       True             19444003
#
#                                                                                                                                   text  \
# 0                            . says he's unsure about the science of climate change. But you don’t need to be a scientist to take ac…
# 1             The National Party declares war on the Gloucester community because they stood up for themselves and won. Remember, the…
# 2                                            This is the same idiot who thought\nThe southern Alberta chinook was climate change lol.
# 3             Communism is Fascism. Fighting Climate Change will Kill millions. Apparently, you're just allowed to say shit on MSNBC.…
# 4              Unmitigated climate change would literally destroy civilization but doing something about it might increase the defici…
# ...                                                                                                                                ...
# 9994                                                                         72% of Americans are 'very worried' about climate change
# 9995                                                   California was given hundreds of millions of dollars over the years to prevent…
# 9996    President Trump believes we should listen to fossil fuel executives and ignore climate change. \n\nI believe we should listen…
# 9997                                                                          Wait til he hears how much climate change is gonna cost
# 9998                                                                                                             Blue marble no more?
#
#      hashtags                                               user_mentions  \
# 0        None                                                  Steve King
# 1        None                                               Rob Oakeshott
# 2        None                                              Suze Michelini
# 3        None                                               Chad Vigorous
# 4        None                                            Ken Klippenstein
# ...       ...                                                         ...
# 9994     None                                             fromhello2hello
# 9995     None  stuntdaddy_42,Justice Faurall,Michael Shelton,Nancy Pelosi
# 9996     None                                              Bernie Sanders
# 9997     None                                                Kate Aronoff
# 9998     None                                                George Takei
#
#                                                                                                         original_tweet_text  \
# 0                                                                                                                      None
# 1     The National Party declares war on the Gloucester community because they stood up for themselves and won. Remember,…
# 2                                  This is the same idiot who thought.The southern Alberta chinook was climate change lol.
# 3     Communism is Fascism. Fighting Climate Change will Kill millions. Apparently, you're just allowed to say shit on MS…
# 4     Unmitigated climate change would literally destroy civilization but doing something about it might increase the def…
# ...                                                                                                                     ...
# 9994                                                              72% of Americans are 'very worried' about climate change
# 9995                                           California was given hundreds of millions of dollars over the years to pre…
# 9996  President Trump believes we should listen to fossil fuel executives and ignore climate change. ..I believe we shoul…
# 9997                                                               Wait til he hears how much climate change is gonna cost
# 9998                                                                                                  Blue marble no more?
#
#      original_tweet_id_str
# 0                     None
# 1      1094332044052549633
# 2      1094384528267902977
# 3      1094379028608438272
# 4      1094311957669265408
# ...                    ...
# 9994   1094339317324017665
# 9995   1093607309606076416
# 9996   1094303164805799936
# 9997   1093996855111966720
# 9998   1094335377194799104
#
# [9999 rows x 10 columns]

# %% [markdown]
# # Q 7 (2 point) Create a new attribute in climate_feed_df named *final_tweet_text*. If *original_tweet_text* is None  then use climate_feed_df.text otherwise use *original_text_tweet* if initial words matched with *climate_feed_df.text* words. If words don't match use climate_feed_df.text
#
# Note that some time after fetching text from a url based on retweeted_status_df.text, we may get different text. We can fix it but for this homework we are ignoring it.

# %%
climate_feed_df.insert(10, "final_tweet_text", None)

for i in range(len(climate_feed_df)):
    if climate_feed_df['original_tweet_text'][i] == None:
        climate_feed_df.at[i, 'final_tweet_text'] = climate_feed_df['text'][i]
    
    elif climate_feed_df['original_tweet_text'][i] == climate_feed_df['text'][i]:
        climate_feed_df.at[i, 'final_tweet_text'] = climate_feed_df['original_tweet_text'][i]
        
    else:
        climate_feed_df.at[i, 'final_tweet_text'] = climate_feed_df['text'][i]
        
climate_feed_df
# Out:
#               created_at  \
# 0    2019-02-10 00:17:31
# 1    2019-02-10 00:17:30
# 2    2019-02-10 00:17:26
# 3    2019-02-10 00:17:24
# 4    2019-02-10 00:17:23
# ...                  ...
# 9994 2019-02-09 20:57:54
# 9995 2019-02-09 20:57:54
# 9996 2019-02-09 20:57:53
# 9997 2019-02-09 20:57:51
# 9998 2019-02-09 20:57:51
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              entities  \
# 0                                                                                                                                                                                                                       {'hashtags': [], 'user_mentions': [{'id_str': '48117116', 'name': 'Steve King', 'screen_name': 'SteveKingIA', 'indices': [1, 13], 'id': 48117116}], 'urls': [{'indices': [117, 140], 'url': 'https://t.co/J1CcrQZkB2', 'display_url': 'twitter.com/i/web/status/1…', 'expanded_url': 'https://twitter.com/i/web/status/1094389867499405313'}], 'symbols': []}
# 1                                                                                                                                                                                                                                                                                                                                                                                                 {'hashtags': [], 'user_mentions': [{'id_str': '16777464', 'name': 'Rob Oakeshott', 'screen_name': 'RobOakeshott1', 'indices': [3, 17], 'id': 16777464}], 'urls': [], 'symbols': []}
# 2                                                                                                                                                                                         {'hashtags': [], 'user_mentions': [{'id_str': '850130990706151428', 'name': 'Suze Michelini', 'screen_name': 'emilia_suze', 'indices': [3, 15], 'id': 850130990706151428}], 'urls': [{'indices': [105, 128], 'url': 'https://t.co/HWjCJGhQIx', 'display_url': 'twitter.com/LeoDiCaprio/st…', 'expanded_url': 'https://twitter.com/LeoDiCaprio/status/1093998640392220673'}], 'symbols': []}
# 3                                                                                                                                                                                                                                                                                                                                                                            {'hashtags': [], 'user_mentions': [{'id_str': '753005970318626816', 'name': 'Chad Vigorous', 'screen_name': 'PrettyBadLefty', 'indices': [3, 18], 'id': 753005970318626816}], 'urls': [], 'symbols': []}
# 4                                                                                                                                                                                                                                                                                                                                                                                        {'hashtags': [], 'user_mentions': [{'id_str': '1634248890', 'name': 'Ken Klippenstein', 'screen_name': 'kenklippenstein', 'indices': [3, 19], 'id': 1634248890}], 'urls': [], 'symbols': []}
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 9994                                                                                                                                      {'hashtags': [], 'user_mentions': [{'id_str': '1073261955216039937', 'name': 'fromhello2hello', 'screen_name': 'fromhello2hello', 'indices': [3, 19], 'id': 1073261955216039937}], 'urls': [{'indices': [78, 101], 'url': 'https://t.co/P1X5jfuUQC', 'display_url': 'treehugger.com/climate-change…', 'expanded_url': 'https://www.treehugger.com/climate-change/72-americans-are-very-worried-about-climate-change.html'}], 'symbols': []}
# 9995  {'hashtags': [], 'user_mentions': [{'id_str': '1082006962995429383', 'name': 'stuntdaddy_42', 'screen_name': 'stuntdaddy_42', 'indices': [3, 17], 'id': 1082006962995429383}, {'id_str': '2497547378', 'name': 'Justice Faurall', 'screen_name': 'JFaurall', 'indices': [19, 28], 'id': 2497547378}, {'id_str': '3073664870', 'name': 'Michael Shelton', 'screen_name': 'MgBenchjeweler', 'indices': [29, 44], 'id': 3073664870}, {'id_str': '15764644', 'name': 'Nancy Pelosi', 'screen_name': 'SpeakerPelosi', 'indices': [45, 59], 'id': 15764644}], 'urls': [], 'symbols...
# 9996                                                                                                                                                                                                                                                                                                                                                                                                {'hashtags': [], 'user_mentions': [{'id_str': '29442313', 'name': 'Bernie Sanders', 'screen_name': 'SenSanders', 'indices': [3, 14], 'id': 29442313}], 'urls': [], 'symbols': []}
# 9997                                                                                                                                                                                                               {'hashtags': [], 'user_mentions': [{'id_str': '637196658', 'name': 'Kate Aronoff', 'screen_name': 'KateAronoff', 'indices': [3, 15], 'id': 637196658}], 'urls': [{'indices': [73, 96], 'url': 'https://t.co/P6znQNsbLH', 'display_url': 'twitter.com/business/statu…', 'expanded_url': 'https://twitter.com/business/status/1093893115633647616'}], 'symbols': []}
# 9998                                                                                                                                                                                                                                                                  {'hashtags': [], 'user_mentions': [{'id_str': '237845487', 'name': 'George Takei', 'screen_name': 'GeorgeTakei', 'indices': [3, 15], 'id': 237845487}], 'urls': [{'indices': [38, 61], 'url': 'https://t.co/hFLndZsiBB', 'display_url': 'po.st/P5AgAW', 'expanded_url': 'http://po.st/P5AgAW'}], 'symbols': []}
#
#       retweeted_status  truncated              user_id  \
# 0                  NaN       True             31476142
# 1         1.094332e+18       True            996782298
# 2         1.094385e+18       True             45333453
# 3         1.094379e+18       True  1020067726532829185
# 4         1.094312e+18       True             19889325
# ...                ...        ...                  ...
# 9994      1.094339e+18       True   888112320097918976
# 9995      1.093607e+18       True           3324836714
# 9996      1.094303e+18       True           1487109794
# 9997      1.093997e+18       True           4737089913
# 9998      1.094335e+18       True             19444003
#
#                                                                                                                                   text  \
# 0                            . says he's unsure about the science of climate change. But you don’t need to be a scientist to take ac…
# 1             The National Party declares war on the Gloucester community because they stood up for themselves and won. Remember, the…
# 2                                            This is the same idiot who thought\nThe southern Alberta chinook was climate change lol.
# 3             Communism is Fascism. Fighting Climate Change will Kill millions. Apparently, you're just allowed to say shit on MSNBC.…
# 4              Unmitigated climate change would literally destroy civilization but doing something about it might increase the defici…
# ...                                                                                                                                ...
# 9994                                                                         72% of Americans are 'very worried' about climate change
# 9995                                                   California was given hundreds of millions of dollars over the years to prevent…
# 9996    President Trump believes we should listen to fossil fuel executives and ignore climate change. \n\nI believe we should listen…
# 9997                                                                          Wait til he hears how much climate change is gonna cost
# 9998                                                                                                             Blue marble no more?
#
#      hashtags                                               user_mentions  \
# 0        None                                                  Steve King
# 1        None                                               Rob Oakeshott
# 2        None                                              Suze Michelini
# 3        None                                               Chad Vigorous
# 4        None                                            Ken Klippenstein
# ...       ...                                                         ...
# 9994     None                                             fromhello2hello
# 9995     None  stuntdaddy_42,Justice Faurall,Michael Shelton,Nancy Pelosi
# 9996     None                                              Bernie Sanders
# 9997     None                                                Kate Aronoff
# 9998     None                                                George Takei
#
#                                                                                                         original_tweet_text  \
# 0                                                                                                                      None
# 1     The National Party declares war on the Gloucester community because they stood up for themselves and won. Remember,…
# 2                                  This is the same idiot who thought.The southern Alberta chinook was climate change lol.
# 3     Communism is Fascism. Fighting Climate Change will Kill millions. Apparently, you're just allowed to say shit on MS…
# 4     Unmitigated climate change would literally destroy civilization but doing something about it might increase the def…
# ...                                                                                                                     ...
# 9994                                                              72% of Americans are 'very worried' about climate change
# 9995                                           California was given hundreds of millions of dollars over the years to pre…
# 9996  President Trump believes we should listen to fossil fuel executives and ignore climate change. ..I believe we shoul…
# 9997                                                               Wait til he hears how much climate change is gonna cost
# 9998                                                                                                  Blue marble no more?
#
#      original_tweet_id_str  \
# 0                     None
# 1      1094332044052549633
# 2      1094384528267902977
# 3      1094379028608438272
# 4      1094311957669265408
# ...                    ...
# 9994   1094339317324017665
# 9995   1093607309606076416
# 9996   1094303164805799936
# 9997   1093996855111966720
# 9998   1094335377194799104
#
#                                                                                                                       final_tweet_text
# 0                            . says he's unsure about the science of climate change. But you don’t need to be a scientist to take ac…
# 1             The National Party declares war on the Gloucester community because they stood up for themselves and won. Remember, the…
# 2                                            This is the same idiot who thought\nThe southern Alberta chinook was climate change lol.
# 3             Communism is Fascism. Fighting Climate Change will Kill millions. Apparently, you're just allowed to say shit on MSNBC.…
# 4              Unmitigated climate change would literally destroy civilization but doing something about it might increase the defici…
# ...                                                                                                                                ...
# 9994                                                                         72% of Americans are 'very worried' about climate change
# 9995                                                   California was given hundreds of millions of dollars over the years to prevent…
# 9996    President Trump believes we should listen to fossil fuel executives and ignore climate change. \n\nI believe we should listen…
# 9997                                                                          Wait til he hears how much climate change is gonna cost
# 9998                                                                                                             Blue marble no more?
#
# [9999 rows x 11 columns]

# %% [markdown]
# # Emoji detection
#
# See this example of emoji as unicode characters

# %%
climate_feed_df['final_tweet_text'].loc[3931]
# Out:
# ' Oh my god, CARBON.......😱😱😱 Cue the outrage machine against smartphone. These things are adding to climate change.'

# %% [markdown]
# We can use use regex to capture this emji
#
# https://apps.timwhitlock.info/emoji/tables/unicode

# %%
emoji_regex = re.compile(r"\U0001F631", re.UNICODE)

# %%
emoji_regex.findall(climate_feed_df['final_tweet_text'].loc[3931])
# Out:
# ['😱', '😱', '😱']

# %% [markdown]
# We'll use emoji library to make this task easier.
#
# Here is some documentation about unicode support in python
#
# https://docs.python.org/3/howto/unicode.html

# %%
! pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.0.0.tar.gz (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.3/197.3 kB 1.9 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Using legacy 'setup.py install' for emoji, since package 'wheel' is not installed.
# Installing collected packages: emoji
#   Running setup.py install for emoji ... done
# Successfully installed emoji-2.0.0

# %%
import emoji

# %%
# emoji.UNICODE_EMOJI
#emoji.distinct_emoji_list

# %% [markdown]
# # Q 8(1 point) Create a column  called *emoji*.  This column should contain a list of tuples for emoji detected in *final_tweet_text*. The first element of the tuple is the emoji detected and second is the text describing the emoji.

# %%
climate_feed_df["emoji"] = climate_feed_df['final_tweet_text'].apply(lambda x: emoji.distinct_emoji_list(x))
climate_feed_df["emoji"][3931]
# Out:
# ['😱']

# %% [markdown]
# # We will use wordcloud  to do elemetary exploratory data analysis (EDA). We will do some cleanup before using wordcloud.
#
# https://github.com/amueller/word_cloud

# %%
# !pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp310-cp310-macosx_10_9_x86_64.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 1.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.6.1 in /Users/rbkraemer/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages (from wordcloud) (1.22.4)
# Requirement already satisfied: matplotlib in /Users/rbkraemer/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: pillow in /Users/rbkraemer/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages (from wordcloud) (9.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/rbkraemer/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.3)
# Requirement already satisfied: cycler>=0.10 in /Users/rbkraemer/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/rbkraemer/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/rbkraemer/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.33.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/rbkraemer/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /Users/rbkraemer/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: six>=1.5 in /Users/rbkraemer/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
text = "climate change. Climate is always changing. Human activity also affects climate through changes in the number and physical properties of tiny solid particles and liquid droplets in the atmosphere, known collectively as atmospheric aerosols"
wordcloud = WordCloud().generate(text)

import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

plt.show()

# %% [markdown]
# As you can see word size is proportional to frequency of a word and highlight the main keywords in a text.
# This gives an idea about the content of the  text.

# %% [markdown]
# We can do all the text pre processing or wrangling
#  like
#
# - More Cleaning
# - Case conversion
# - Spell correction
# - Expanding contractions
# - Removing stop words
# - Morphological normalization
#     - Stemming
#     - Lemmatization
#
#
# But for this homework we'll only **do expanding contractions,  stop words removal,  and lemmatization**

# %% [markdown]
# # Q 9 (2 = .5+.5+.5+.5 points) Do
# - expanding contractions
# - stop words removal
# - lemmatization
# - Use wordcloud to visualize keywords

# %%
# !pip install contractions
# Out:
# Collecting contractions
#   Downloading contractions-0.1.72-py2.py3-none-any.whl (8.3 kB)
# Collecting textsearch>=0.0.21
#   Downloading textsearch-0.0.21-py2.py3-none-any.whl (7.5 kB)
# Collecting pyahocorasick
#   Downloading pyahocorasick-1.4.4-cp310-cp310-macosx_10_9_x86_64.whl (32 kB)
# Collecting anyascii
#   Downloading anyascii-0.3.1-py3-none-any.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.5/287.5 kB 2.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.1 contractions-0.1.72 pyahocorasick-1.4.4 textsearch-0.0.21

# %%
import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
import contractions
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:997)>
# [nltk_data] Error loading stopwords: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:997)>

# %%
text = """

"""
for i in range(len( climate_feed_df)):
    text += climate_feed_df['final_tweet_text'][i]

text_tokens = word_tokenize(text)
tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]
text_without_sw = (" ").join(tokens_without_sw)

expanded_words = []   
for word in text_without_sw.split():
    expanded_words.append(contractions.fix(word)) 

lemmed = []    
lemmatizer = WordNetLemmatizer()

for lem in expanded_words: 
    lemmed.append(lemmatizer.lemmatize(word))

full_text = ' '.join(lemmed)
    
wordcloud = WordCloud().generate(complete_text)

import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Input In [43], in <cell line: 7>()
#       4 for i in range(len( climate_feed_df)):
#       5     text += climate_feed_df['final_tweet_text'][i]
# ----> 7 text_tokens = word_tokenize(text)
#       8 tokens_without_sw = [word for word in text_tokens if not word in stopwords.words()]
#       9 text_without_sw = (" ").join(tokens_without_sw)
#
# File ~/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages/nltk/tokenize/__init__.py:129, in word_tokenize(text, language, preserve_line)
#     114 def word_tokenize(text, language="english", preserve_line=False):
#     115     """
#     116     Return a tokenized copy of *text*,
#     117     using NLTK's recommended word tokenizer
#    (...)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     132     ]
#
# File ~/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages/nltk/tokenize/__init__.py:106, in sent_tokenize(text, language)
#      96 def sent_tokenize(text, language="english"):
#      97     """
#      98     Return a sentence-tokenized copy of *text*,
#      99     using NLTK's recommended sentence tokenizer
#    (...)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#
# File ~/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages/nltk/data.py:750, in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     747     print(f"<<Loading {resource_url}>>")
#     749 # Load the resource.
# --> 750 opened_resource = _open(resource_url)
#     752 if format == "raw":
#     753     resource_val = opened_resource.read()
#
# File ~/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages/nltk/data.py:876, in _open(resource_url)
#     873 protocol, path_ = split_resource_url(resource_url)
#     875 if protocol is None or protocol.lower() == "nltk":
# --> 876     return find(path_, path + [""]).open()
#     877 elif protocol.lower() == "file":
#     878     # urllib might not use mode='rb', so handle this one ourselves:
#     879     return find(path_, [""]).open()
#
# File ~/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages/nltk/data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/PY3/english.pickle
#
#   Searched in:
#     - '/Users/rbkraemer/nltk_data'
#     - '/Users/rbkraemer/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/nltk_data'
#     - '/Users/rbkraemer/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/share/nltk_data'
#     - '/Users/rbkraemer/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************

# %% [markdown]
# # Homework ends
# # Final thoughts
# We did not do all of the cleanup or used all attributes for EDA. Let us highlight one more cleanup activity related to language.

# %%
import enchant
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [45], in <cell line: 1>()
# ----> 1 import enchant
#
# File ~/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages/enchant/__init__.py:81, in <module>
#      78 import warnings
#      80 try:
# ---> 81     from enchant import _enchant as _e
#      82 except ImportError:
#      83     if not os.environ.get("PYENCHANT_IGNORE_MISSING_LIB", False):
#
# File ~/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages/enchant/_enchant.py:157, in <module>
#     149 if enchant_lib_path is None:
#     150     msg = textwrap.dedent(
#     151         """\
#     152         The 'enchant' C library was not found and maybe needs to be installed.
#    (...)
#     155         """
#     156     )
# --> 157     raise ImportError(msg)
#     160 find_message("loading library ", enchant_lib_path)
#     161 e = ctypes.cdll.LoadLibrary(enchant_lib_path)
#
# ImportError: The 'enchant' C library was not found and maybe needs to be installed.
# See  https://pyenchant.github.io/pyenchant/install.html
# for details

# %%
dictionary = enchant.Dict('en')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 dictionary = enchant.Dict('en')
#
# NameError: name 'enchant' is not defined

# %%
climate_feed_df['text'].loc[5217]
# Out:
# '去LACMA那么多次，都没意识到旁边的Tar Pits是啥…\n一直以为是摆几个造型给小朋友们玩的公园…\n站在千年前的point看千年后的楼宇车辆，再一想climate change，千年后人类可能也不存在了就觉得——有点兴奋'

# %%
[dictionary.check(w) for w in  nltk.word_tokenize(climate_feed_df['text'].loc[5217])]
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 [dictionary.check(w) for w in  nltk.word_tokenize(climate_feed_df['text'].loc[5217])]
#
# File ~/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages/nltk/tokenize/__init__.py:129, in word_tokenize(text, language, preserve_line)
#     114 def word_tokenize(text, language="english", preserve_line=False):
#     115     """
#     116     Return a tokenized copy of *text*,
#     117     using NLTK's recommended word tokenizer
#    (...)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     132     ]
#
# File ~/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages/nltk/tokenize/__init__.py:106, in sent_tokenize(text, language)
#      96 def sent_tokenize(text, language="english"):
#      97     """
#      98     Return a sentence-tokenized copy of *text*,
#      99     using NLTK's recommended sentence tokenizer
#    (...)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#
# File ~/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages/nltk/data.py:750, in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     747     print(f"<<Loading {resource_url}>>")
#     749 # Load the resource.
# --> 750 opened_resource = _open(resource_url)
#     752 if format == "raw":
#     753     resource_val = opened_resource.read()
#
# File ~/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages/nltk/data.py:876, in _open(resource_url)
#     873 protocol, path_ = split_resource_url(resource_url)
#     875 if protocol is None or protocol.lower() == "nltk":
# --> 876     return find(path_, path + [""]).open()
#     877 elif protocol.lower() == "file":
#     878     # urllib might not use mode='rb', so handle this one ourselves:
#     879     return find(path_, [""]).open()
#
# File ~/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/python3.10/site-packages/nltk/data.py:583, in find(resource_name, paths)
#     581 sep = "*" * 70
#     582 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource punkt not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('punkt')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load tokenizers/punkt/PY3/english.pickle
#
#   Searched in:
#     - '/Users/rbkraemer/nltk_data'
#     - '/Users/rbkraemer/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/nltk_data'
#     - '/Users/rbkraemer/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/share/nltk_data'
#     - '/Users/rbkraemer/Documents/DU/Q5_Summer_2022/comp_4447/dst1_env/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
#     - ''
# **********************************************************************
